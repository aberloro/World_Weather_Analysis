# %%
#Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
import requests
import time
from datetime import datetime 
from config import weather_api_key

# %%
#Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#unzip latitudes and longitudes to a tuple 
coordinates = list(lat_lngs)

# %%
#Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

#Print the city count to confirm sufficient count.
len(cities)
# Out:
# 748

# %%
#Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create an empty list to hold the weather data.
city_data = []

#Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
 
    # Run API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print(city + " not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dombas
# Processing Record 2 of Set 1 | fuxin
# Processing Record 3 of Set 1 | ermelo
# Processing Record 4 of Set 1 | newport beach
# Processing Record 5 of Set 1 | khatanga
# Processing Record 6 of Set 1 | samusu
# samusu not found. Skipping...
# Processing Record 7 of Set 1 | tazovskiy
# Processing Record 8 of Set 1 | barrow
# Processing Record 9 of Set 1 | urdzhar
# urdzhar not found. Skipping...
# Processing Record 10 of Set 1 | butaritari
# Processing Record 11 of Set 1 | bluff
# Processing Record 12 of Set 1 | new norfolk
# Processing Record 13 of Set 1 | orocue
# Processing Record 14 of Set 1 | akdepe
# Processing Record 15 of Set 1 | illoqqortoormiut
# illoqqortoormiut not found. Skipping...
# Processing Record 16 of Set 1 | hasaki
# Processing Record 17 of Set 1 | torbay
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | bandarbeyla
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | san quintin
# Processing Record 23 of Set 1 | stoyba
# stoyba not found. Skipping...
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | amderma
# amderma not found. Skipping...
# Processing Record 26 of Set 1 | kushima
# Processing Record 27 of Set 1 | yellowknife
# Processing Record 28 of Set 1 | mattru
# Processing Record 29 of Set 1 | gwembe
# Processing Record 30 of Set 1 | taolanaro
# taolanaro not found. Skipping...
# Processing Record 31 of Set 1 | umm lajj
# Processing Record 32 of Set 1 | wellington
# Processing Record 33 of Set 1 | saint-joseph
# Processing Record 34 of Set 1 | camopi
# Processing Record 35 of Set 1 | atuona
# Processing Record 36 of Set 1 | pringsewu
# Processing Record 37 of Set 1 | bethel
# Processing Record 38 of Set 1 | palabuhanratu
# palabuhanratu not found. Skipping...
# Processing Record 39 of Set 1 | santa isabel
# Processing Record 40 of Set 1 | poronaysk
# Processing Record 41 of Set 1 | mys shmidta
# mys shmidta not found. Skipping...
# Processing Record 42 of Set 1 | busselton
# Processing Record 43 of Set 1 | souillac
# Processing Record 44 of Set 1 | faanui
# Processing Record 45 of Set 1 | avera
# Processing Record 46 of Set 1 | tasiilaq
# Processing Record 47 of Set 1 | clyde river
# Processing Record 48 of Set 1 | dingle
# Processing Record 49 of Set 1 | tsaratanana
# Processing Record 50 of Set 1 | hobart
# Processing Record 1 of Set 2 | esso
# Processing Record 2 of Set 2 | longyearbyen
# Processing Record 3 of Set 2 | pacific grove
# Processing Record 4 of Set 2 | east london
# Processing Record 5 of Set 2 | ilo
# Processing Record 6 of Set 2 | thaton
# Processing Record 7 of Set 2 | pisco
# Processing Record 8 of Set 2 | vestmannaeyjar
# Processing Record 9 of Set 2 | srednekolymsk
# Processing Record 10 of Set 2 | esperance
# Processing Record 11 of Set 2 | mana
# Processing Record 12 of Set 2 | kazalinsk
# kazalinsk not found. Skipping...
# Processing Record 13 of Set 2 | ville-marie
# Processing Record 14 of Set 2 | hermanus
# Processing Record 15 of Set 2 | coquimbo
# Processing Record 16 of Set 2 | cherskiy
# Processing Record 17 of Set 2 | codrington
# Processing Record 18 of Set 2 | antofagasta
# Processing Record 19 of Set 2 | nizhneyansk
# nizhneyansk not found. Skipping...
# Processing Record 20 of Set 2 | inhambane
# Processing Record 21 of Set 2 | kendari
# Processing Record 22 of Set 2 | cape town
# Processing Record 23 of Set 2 | thompson
# Processing Record 24 of Set 2 | cabo san lucas
# Processing Record 25 of Set 2 | chizhou
# Processing Record 26 of Set 2 | rikitea
# Processing Record 27 of Set 2 | luderitz
# Processing Record 28 of Set 2 | havre-saint-pierre
# Processing Record 29 of Set 2 | nha trang
# Processing Record 30 of Set 2 | carnarvon
# Processing Record 31 of Set 2 | ouro preto do oeste
# Processing Record 32 of Set 2 | lebu
# Processing Record 33 of Set 2 | oneonta
# Processing Record 34 of Set 2 | nome
# Processing Record 35 of Set 2 | mar del plata
# Processing Record 36 of Set 2 | okhotsk
# Processing Record 37 of Set 2 | hithadhoo
# Processing Record 38 of Set 2 | husavik
# Processing Record 39 of Set 2 | sitka
# Processing Record 40 of Set 2 | scottsburgh
# scottsburgh not found. Skipping...
# Processing Record 41 of Set 2 | jizan
# Processing Record 42 of Set 2 | los cordobas
# Processing Record 43 of Set 2 | bredasdorp
# Processing Record 44 of Set 2 | petropavlovka
# Processing Record 45 of Set 2 | nanortalik
# Processing Record 46 of Set 2 | kapaa
# Processing Record 47 of Set 2 | basco
# Processing Record 48 of Set 2 | na klang
# Processing Record 49 of Set 2 | asfi
# Processing Record 50 of Set 2 | pimentel
# Processing Record 1 of Set 3 | albany
# Processing Record 2 of Set 3 | ilulissat
# Processing Record 3 of Set 3 | fairbanks
# Processing Record 4 of Set 3 | merritt
# Processing Record 5 of Set 3 | saint-philippe
# Processing Record 6 of Set 3 | te anau
# Processing Record 7 of Set 3 | kodiak
# Processing Record 8 of Set 3 | shakhtinsk
# Processing Record 9 of Set 3 | saint-pierre
# Processing Record 10 of Set 3 | dryden
# Processing Record 11 of Set 3 | puerto escondido
# Processing Record 12 of Set 3 | emba
# Processing Record 13 of Set 3 | dunedin
# Processing Record 14 of Set 3 | osypenko
# Processing Record 15 of Set 3 | georgetown
# Processing Record 16 of Set 3 | taoudenni
# Processing Record 17 of Set 3 | santiago del estero
# Processing Record 18 of Set 3 | pangnirtung
# Processing Record 19 of Set 3 | kalaleh
# Processing Record 20 of Set 3 | lishu
# Processing Record 21 of Set 3 | tsihombe
# tsihombe not found. Skipping...
# Processing Record 22 of Set 3 | ixtapa
# Processing Record 23 of Set 3 | jamestown
# Processing Record 24 of Set 3 | dikson
# Processing Record 25 of Set 3 | lavrentiya
# Processing Record 26 of Set 3 | bambous virieux
# Processing Record 27 of Set 3 | ponta do sol
# Processing Record 28 of Set 3 | poum
# Processing Record 29 of Set 3 | tooele
# Processing Record 30 of Set 3 | tautira
# Processing Record 31 of Set 3 | saldanha
# Processing Record 32 of Set 3 | mikkeli
# Processing Record 33 of Set 3 | yirol
# yirol not found. Skipping...
# Processing Record 34 of Set 3 | beloha
# Processing Record 35 of Set 3 | hambantota
# Processing Record 36 of Set 3 | ozernovskiy
# Processing Record 37 of Set 3 | ekibastuz
# Processing Record 38 of Set 3 | cancun
# Processing Record 39 of Set 3 | waingapu
# Processing Record 40 of Set 3 | delijan
# Processing Record 41 of Set 3 | huejuquilla el alto
# Processing Record 42 of Set 3 | avarua
# Processing Record 43 of Set 3 | belushya guba
# belushya guba not found. Skipping...
# Processing Record 44 of Set 3 | saleaula
# saleaula not found. Skipping...
# Processing Record 45 of Set 3 | port-gentil
# Processing Record 46 of Set 3 | sao joao da barra
# Processing Record 47 of Set 3 | bolshegrivskoye
# bolshegrivskoye not found. Skipping...
# Processing Record 48 of Set 3 | mentok
# mentok not found. Skipping...
# Processing Record 49 of Set 3 | sayyan
# Processing Record 50 of Set 3 | aykhal
# Processing Record 1 of Set 4 | bolungarvik
# bolungarvik not found. Skipping...
# Processing Record 2 of Set 4 | galesong
# Processing Record 3 of Set 4 | mahebourg
# Processing Record 4 of Set 4 | kralendijk
# Processing Record 5 of Set 4 | port elizabeth
# Processing Record 6 of Set 4 | mayor pablo lagerenza
# Processing Record 7 of Set 4 | touros
# Processing Record 8 of Set 4 | mount gambier
# Processing Record 9 of Set 4 | rafraf
# Processing Record 10 of Set 4 | miandrivazo
# Processing Record 11 of Set 4 | carlagan
# Processing Record 12 of Set 4 | phan rang
# phan rang not found. Skipping...
# Processing Record 13 of Set 4 | inderborskiy
# inderborskiy not found. Skipping...
# Processing Record 14 of Set 4 | salalah
# Processing Record 15 of Set 4 | hereford
# Processing Record 16 of Set 4 | poddorye
# Processing Record 17 of Set 4 | san patricio
# Processing Record 18 of Set 4 | pilar
# Processing Record 19 of Set 4 | waipawa
# Processing Record 20 of Set 4 | caraballeda
# Processing Record 21 of Set 4 | tam ky
# Processing Record 22 of Set 4 | port lincoln
# Processing Record 23 of Set 4 | vaini
# Processing Record 24 of Set 4 | hobyo
# Processing Record 25 of Set 4 | belmonte
# Processing Record 26 of Set 4 | muros
# Processing Record 27 of Set 4 | banjar
# Processing Record 28 of Set 4 | amos
# Processing Record 29 of Set 4 | ahipara
# Processing Record 30 of Set 4 | vardo
# Processing Record 31 of Set 4 | culiacan
# Processing Record 32 of Set 4 | bukachacha
# Processing Record 33 of Set 4 | klaksvik
# Processing Record 34 of Set 4 | lata
# Processing Record 35 of Set 4 | ortigueira
# Processing Record 36 of Set 4 | nagod
# Processing Record 37 of Set 4 | tulun
# Processing Record 38 of Set 4 | vila franca do campo
# Processing Record 39 of Set 4 | maniitsoq
# Processing Record 40 of Set 4 | suntar
# Processing Record 41 of Set 4 | tuktoyaktuk
# Processing Record 42 of Set 4 | bengkulu
# Processing Record 43 of Set 4 | mitu
# Processing Record 44 of Set 4 | adrar
# Processing Record 45 of Set 4 | komsomolskiy
# Processing Record 46 of Set 4 | sakaiminato
# Processing Record 47 of Set 4 | dosso
# Processing Record 48 of Set 4 | grindavik
# Processing Record 49 of Set 4 | shu
# Processing Record 50 of Set 4 | ruatoria
# ruatoria not found. Skipping...
# Processing Record 1 of Set 5 | palmer
# Processing Record 2 of Set 5 | saskylakh
# Processing Record 3 of Set 5 | mocuba
# Processing Record 4 of Set 5 | shanting
# Processing Record 5 of Set 5 | ilhabela
# Processing Record 6 of Set 5 | abashiri
# Processing Record 7 of Set 5 | flin flon
# Processing Record 8 of Set 5 | kedrovyy
# Processing Record 9 of Set 5 | preobrazheniye
# Processing Record 10 of Set 5 | hovd
# Processing Record 11 of Set 5 | crab hill
# crab hill not found. Skipping...
# Processing Record 12 of Set 5 | salme
# Processing Record 13 of Set 5 | hammerfest
# Processing Record 14 of Set 5 | port alfred
# Processing Record 15 of Set 5 | yar-sale
# Processing Record 16 of Set 5 | hilo
# Processing Record 17 of Set 5 | sao filipe
# Processing Record 18 of Set 5 | maues
# Processing Record 19 of Set 5 | katherine
# Processing Record 20 of Set 5 | zhuhai
# Processing Record 21 of Set 5 | zalantun
# Processing Record 22 of Set 5 | malanje
# Processing Record 23 of Set 5 | ovsyanka
# Processing Record 24 of Set 5 | qaanaaq
# Processing Record 25 of Set 5 | pavlysh
# Processing Record 26 of Set 5 | lompoc
# Processing Record 27 of Set 5 | san felipe
# Processing Record 28 of Set 5 | nikolskoye
# Processing Record 29 of Set 5 | ayr
# Processing Record 30 of Set 5 | airai
# Processing Record 31 of Set 5 | puqi
# Processing Record 32 of Set 5 | norman wells
# Processing Record 33 of Set 5 | warqla
# warqla not found. Skipping...
# Processing Record 34 of Set 5 | clonakilty
# Processing Record 35 of Set 5 | guerrero negro
# Processing Record 36 of Set 5 | vanimo
# Processing Record 37 of Set 5 | kaitangata
# Processing Record 38 of Set 5 | muzhi
# Processing Record 39 of Set 5 | verkhnetulomskiy
# Processing Record 40 of Set 5 | sampit
# Processing Record 41 of Set 5 | bachatskiy
# Processing Record 42 of Set 5 | puerto colombia
# Processing Record 43 of Set 5 | caravelas
# Processing Record 44 of Set 5 | mahanoro
# Processing Record 45 of Set 5 | kruisfontein
# Processing Record 46 of Set 5 | soma
# Processing Record 47 of Set 5 | mogadishu
# Processing Record 48 of Set 5 | barawe
# barawe not found. Skipping...
# Processing Record 49 of Set 5 | mucuri
# Processing Record 50 of Set 5 | port hardy
# Processing Record 1 of Set 6 | laguna
# Processing Record 2 of Set 6 | severo-kurilsk
# Processing Record 3 of Set 6 | villazon
# Processing Record 4 of Set 6 | bowen
# Processing Record 5 of Set 6 | yamada
# Processing Record 6 of Set 6 | presidencia roque saenz pena
# Processing Record 7 of Set 6 | lae
# Processing Record 8 of Set 6 | yomitan
# yomitan not found. Skipping...
# Processing Record 9 of Set 6 | wulanhaote
# wulanhaote not found. Skipping...
# Processing Record 10 of Set 6 | yenagoa
# Processing Record 11 of Set 6 | buala
# Processing Record 12 of Set 6 | ilebo
# Processing Record 13 of Set 6 | honningsvag
# Processing Record 14 of Set 6 | majene
# Processing Record 15 of Set 6 | zhigansk
# Processing Record 16 of Set 6 | lorengau
# Processing Record 17 of Set 6 | manggar
# Processing Record 18 of Set 6 | rocha
# Processing Record 19 of Set 6 | surt
# Processing Record 20 of Set 6 | bathsheba
# Processing Record 21 of Set 6 | victoria
# Processing Record 22 of Set 6 | half moon bay
# Processing Record 23 of Set 6 | tumannyy
# tumannyy not found. Skipping...
# Processing Record 24 of Set 6 | yerbogachen
# Processing Record 25 of Set 6 | kavaratti
# Processing Record 26 of Set 6 | nicolas bravo
# Processing Record 27 of Set 6 | meulaboh
# Processing Record 28 of Set 6 | shirokovskiy
# Processing Record 29 of Set 6 | provideniya
# Processing Record 30 of Set 6 | praia da vitoria
# Processing Record 31 of Set 6 | leshukonskoye
# Processing Record 32 of Set 6 | aracruz
# Processing Record 33 of Set 6 | acari
# Processing Record 34 of Set 6 | portland
# Processing Record 35 of Set 6 | chiredzi
# Processing Record 36 of Set 6 | saint-augustin
# Processing Record 37 of Set 6 | kirakira
# Processing Record 38 of Set 6 | launceston
# Processing Record 39 of Set 6 | chokurdakh
# Processing Record 40 of Set 6 | zyryanka
# Processing Record 41 of Set 6 | ostrovnoy
# Processing Record 42 of Set 6 | rundu
# Processing Record 43 of Set 6 | zlatoustovsk
# zlatoustovsk not found. Skipping...
# Processing Record 44 of Set 6 | naftah
# naftah not found. Skipping...
# Processing Record 45 of Set 6 | haines junction
# Processing Record 46 of Set 6 | olafsvik
# Processing Record 47 of Set 6 | barbar
# barbar not found. Skipping...
# Processing Record 48 of Set 6 | tuensang
# Processing Record 49 of Set 6 | isla mujeres
# Processing Record 50 of Set 6 | tame
# Processing Record 1 of Set 7 | broome
# Processing Record 2 of Set 7 | attawapiskat
# attawapiskat not found. Skipping...
# Processing Record 3 of Set 7 | marathon
# Processing Record 4 of Set 7 | porto belo
# Processing Record 5 of Set 7 | cidreira
# Processing Record 6 of Set 7 | takhtamygda
# Processing Record 7 of Set 7 | killarney
# Processing Record 8 of Set 7 | shimoda
# Processing Record 9 of Set 7 | vila velha
# Processing Record 10 of Set 7 | zaragoza
# Processing Record 11 of Set 7 | evensk
# Processing Record 12 of Set 7 | cockburn harbour
# cockburn harbour not found. Skipping...
# Processing Record 13 of Set 7 | mareeba
# Processing Record 14 of Set 7 | dubbo
# Processing Record 15 of Set 7 | vao
# Processing Record 16 of Set 7 | sola
# Processing Record 17 of Set 7 | kavieng
# Processing Record 18 of Set 7 | ribeira grande
# Processing Record 19 of Set 7 | berlevag
# Processing Record 20 of Set 7 | enna
# Processing Record 21 of Set 7 | samana
# Processing Record 22 of Set 7 | raudeberg
# Processing Record 23 of Set 7 | plettenberg bay
# Processing Record 24 of Set 7 | margate
# Processing Record 25 of Set 7 | kolpashevo
# Processing Record 26 of Set 7 | leningradskiy
# Processing Record 27 of Set 7 | narsaq
# Processing Record 28 of Set 7 | nargana
# Processing Record 29 of Set 7 | saryg-sep
# Processing Record 30 of Set 7 | lagoa
# Processing Record 31 of Set 7 | qaqortoq
# Processing Record 32 of Set 7 | nhulunbuy
# Processing Record 33 of Set 7 | west wendover
# Processing Record 34 of Set 7 | beringovskiy
# Processing Record 35 of Set 7 | catania
# Processing Record 36 of Set 7 | jasper
# Processing Record 37 of Set 7 | ozgon
# ozgon not found. Skipping...
# Processing Record 38 of Set 7 | upernavik
# Processing Record 39 of Set 7 | shestakovo
# Processing Record 40 of Set 7 | lodwar
# Processing Record 41 of Set 7 | berbera
# Processing Record 42 of Set 7 | chuy
# Processing Record 43 of Set 7 | we
# we not found. Skipping...
# Processing Record 44 of Set 7 | lazo
# Processing Record 45 of Set 7 | shelburne
# Processing Record 46 of Set 7 | dudinka
# Processing Record 47 of Set 7 | waghai
# Processing Record 48 of Set 7 | ishinomaki
# Processing Record 49 of Set 7 | verkhnyaya inta
# Processing Record 50 of Set 7 | nanfeng
# Processing Record 1 of Set 8 | stuttgart
# Processing Record 2 of Set 8 | chagda
# chagda not found. Skipping...
# Processing Record 3 of Set 8 | pozo colorado
# Processing Record 4 of Set 8 | chuchkovo
# Processing Record 5 of Set 8 | boguchany
# Processing Record 6 of Set 8 | mackay
# Processing Record 7 of Set 8 | wasilla
# Processing Record 8 of Set 8 | hauterive
# Processing Record 9 of Set 8 | conselheiro pena
# Processing Record 10 of Set 8 | beyneu
# Processing Record 11 of Set 8 | mahon
# Processing Record 12 of Set 8 | port augusta
# Processing Record 13 of Set 8 | gat
# Processing Record 14 of Set 8 | aljezur
# Processing Record 15 of Set 8 | myski
# Processing Record 16 of Set 8 | tura
# Processing Record 17 of Set 8 | alofi
# Processing Record 18 of Set 8 | mahibadhoo
# Processing Record 19 of Set 8 | velika obarska
# Processing Record 20 of Set 8 | klyuchi
# Processing Record 21 of Set 8 | tahoua
# Processing Record 22 of Set 8 | road town
# Processing Record 23 of Set 8 | ada
# Processing Record 24 of Set 8 | wanning
# Processing Record 25 of Set 8 | sheridan
# Processing Record 26 of Set 8 | bellefontaine
# Processing Record 27 of Set 8 | yavoriv
# Processing Record 28 of Set 8 | izumo
# Processing Record 29 of Set 8 | pevek
# Processing Record 30 of Set 8 | saint-michel-des-saints
# Processing Record 31 of Set 8 | rosamorada
# Processing Record 32 of Set 8 | kattivakkam
# Processing Record 33 of Set 8 | horn lake
# Processing Record 34 of Set 8 | oranjemund
# Processing Record 35 of Set 8 | tyler
# Processing Record 36 of Set 8 | kanniyakumari
# Processing Record 37 of Set 8 | barentsburg
# barentsburg not found. Skipping...
# Processing Record 38 of Set 8 | sadiqabad
# Processing Record 39 of Set 8 | ullapool
# Processing Record 40 of Set 8 | puerto madryn
# Processing Record 41 of Set 8 | galle
# Processing Record 42 of Set 8 | ducheng
# Processing Record 43 of Set 8 | apozol
# Processing Record 44 of Set 8 | alta floresta
# Processing Record 45 of Set 8 | berea
# Processing Record 46 of Set 8 | balkanabat
# Processing Record 47 of Set 8 | arraial do cabo
# Processing Record 48 of Set 8 | fort-shevchenko
# Processing Record 49 of Set 8 | labuhan
# Processing Record 50 of Set 8 | akyab
# Processing Record 1 of Set 9 | lima
# Processing Record 2 of Set 9 | novobureyskiy
# Processing Record 3 of Set 9 | omsukchan
# Processing Record 4 of Set 9 | chudniv
# Processing Record 5 of Set 9 | mazamari
# Processing Record 6 of Set 9 | huanan
# Processing Record 7 of Set 9 | los llanos de aridane
# Processing Record 8 of Set 9 | salinopolis
# Processing Record 9 of Set 9 | porto novo
# Processing Record 10 of Set 9 | taltal
# Processing Record 11 of Set 9 | cururupu
# Processing Record 12 of Set 9 | daxian
# daxian not found. Skipping...
# Processing Record 13 of Set 9 | cayenne
# Processing Record 14 of Set 9 | krasnyye chetai
# Processing Record 15 of Set 9 | makakilo city
# Processing Record 16 of Set 9 | vestmanna
# Processing Record 17 of Set 9 | yeppoon
# Processing Record 18 of Set 9 | kirovskiy
# Processing Record 19 of Set 9 | ca mau
# Processing Record 20 of Set 9 | fara in sabina
# Processing Record 21 of Set 9 | moquegua
# Processing Record 22 of Set 9 | qasigiannguit
# Processing Record 23 of Set 9 | tianpeng
# Processing Record 24 of Set 9 | fortuna
# Processing Record 25 of Set 9 | eyl
# Processing Record 26 of Set 9 | bremervorde
# Processing Record 27 of Set 9 | danshui
# Processing Record 28 of Set 9 | morant bay
# Processing Record 29 of Set 9 | rawson
# Processing Record 30 of Set 9 | puerto del rosario
# Processing Record 31 of Set 9 | severnyy
# Processing Record 32 of Set 9 | iqaluit
# Processing Record 33 of Set 9 | constantine
# Processing Record 34 of Set 9 | scarborough
# Processing Record 35 of Set 9 | vostok
# Processing Record 36 of Set 9 | awbari
# Processing Record 37 of Set 9 | las palmas
# Processing Record 38 of Set 9 | grand gaube
# Processing Record 39 of Set 9 | ngukurr
# ngukurr not found. Skipping...
# Processing Record 40 of Set 9 | manutuke
# Processing Record 41 of Set 9 | gujranwala
# Processing Record 42 of Set 9 | watertown
# Processing Record 43 of Set 9 | pinega
# Processing Record 44 of Set 9 | sirur
# Processing Record 45 of Set 9 | zboriste
# Processing Record 46 of Set 9 | sartell
# Processing Record 47 of Set 9 | hami
# Processing Record 48 of Set 9 | kasempa
# Processing Record 49 of Set 9 | san cristobal
# Processing Record 50 of Set 9 | pakwach
# pakwach not found. Skipping...
# Processing Record 1 of Set 10 | hofn
# Processing Record 2 of Set 10 | treinta y tres
# Processing Record 3 of Set 10 | carutapera
# Processing Record 4 of Set 10 | port hedland
# Processing Record 5 of Set 10 | calvinia
# Processing Record 6 of Set 10 | lethem
# Processing Record 7 of Set 10 | providencia
# Processing Record 8 of Set 10 | namie
# Processing Record 9 of Set 10 | mildura
# Processing Record 10 of Set 10 | trairi
# Processing Record 11 of Set 10 | puri
# Processing Record 12 of Set 10 | karratha
# Processing Record 13 of Set 10 | oktyabrskiy
# Processing Record 14 of Set 10 | moerai
# Processing Record 15 of Set 10 | zhongxing
# Processing Record 16 of Set 10 | buguda
# Processing Record 17 of Set 10 | brigantine
# Processing Record 18 of Set 10 | hildburghausen
# Processing Record 19 of Set 10 | mullaitivu
# mullaitivu not found. Skipping...
# Processing Record 20 of Set 10 | ulladulla
# Processing Record 21 of Set 10 | kysyl-syr
# Processing Record 22 of Set 10 | pampas
# Processing Record 23 of Set 10 | vaitupu
# vaitupu not found. Skipping...
# Processing Record 24 of Set 10 | yulara
# Processing Record 25 of Set 10 | maumere
# Processing Record 26 of Set 10 | dwarka
# Processing Record 27 of Set 10 | udankudi
# Processing Record 28 of Set 10 | roma
# Processing Record 29 of Set 10 | mergui
# mergui not found. Skipping...
# Processing Record 30 of Set 10 | irtyshskiy
# Processing Record 31 of Set 10 | manokwari
# Processing Record 32 of Set 10 | gweru
# Processing Record 33 of Set 10 | linhares
# Processing Record 34 of Set 10 | asyut
# Processing Record 35 of Set 10 | sun valley
# Processing Record 36 of Set 10 | okato
# Processing Record 37 of Set 10 | okha
# Processing Record 38 of Set 10 | flinders
# Processing Record 39 of Set 10 | trezzo
# trezzo not found. Skipping...
# Processing Record 40 of Set 10 | punta alta
# Processing Record 41 of Set 10 | tuatapere
# Processing Record 42 of Set 10 | port macquarie
# Processing Record 43 of Set 10 | castro
# Processing Record 44 of Set 10 | concordia
# Processing Record 45 of Set 10 | sungaipenuh
# Processing Record 46 of Set 10 | kirkwall
# Processing Record 47 of Set 10 | najran
# Processing Record 48 of Set 10 | posse
# Processing Record 49 of Set 10 | bitkine
# Processing Record 50 of Set 10 | quatre cocos
# Processing Record 1 of Set 11 | vanatori
# Processing Record 2 of Set 11 | temerloh
# Processing Record 3 of Set 11 | port blair
# Processing Record 4 of Set 11 | marcona
# marcona not found. Skipping...
# Processing Record 5 of Set 11 | andros town
# Processing Record 6 of Set 11 | chandbali
# Processing Record 7 of Set 11 | hunza
# hunza not found. Skipping...
# Processing Record 8 of Set 11 | faya
# Processing Record 9 of Set 11 | mizan teferi
# Processing Record 10 of Set 11 | ogaminana
# Processing Record 11 of Set 11 | coihaique
# Processing Record 12 of Set 11 | newark
# Processing Record 13 of Set 11 | calabozo
# Processing Record 14 of Set 11 | nakhon thai
# Processing Record 15 of Set 11 | benghazi
# Processing Record 16 of Set 11 | bela
# Processing Record 17 of Set 11 | burgos
# Processing Record 18 of Set 11 | tynda
# Processing Record 19 of Set 11 | takoradi
# Processing Record 20 of Set 11 | north platte
# Processing Record 21 of Set 11 | aklavik
# Processing Record 22 of Set 11 | ust-ilimsk
# Processing Record 23 of Set 11 | cercal
# Processing Record 24 of Set 11 | saint-paul
# Processing Record 25 of Set 11 | kabare
# Processing Record 26 of Set 11 | praia
# Processing Record 27 of Set 11 | debre sina
# Processing Record 28 of Set 11 | nobeoka
# Processing Record 29 of Set 11 | rincon
# Processing Record 30 of Set 11 | hirara
# Processing Record 31 of Set 11 | sinop
# Processing Record 32 of Set 11 | fukue
# Processing Record 33 of Set 11 | takikawa
# Processing Record 34 of Set 11 | nemuro
# Processing Record 35 of Set 11 | paamiut
# Processing Record 36 of Set 11 | baruun-urt
# Processing Record 37 of Set 11 | lagos
# Processing Record 38 of Set 11 | mehamn
# Processing Record 39 of Set 11 | saint george
# Processing Record 40 of Set 11 | sambava
# Processing Record 41 of Set 11 | rafai
# Processing Record 42 of Set 11 | korla
# Processing Record 43 of Set 11 | thaba-tseka
# Processing Record 44 of Set 11 | carballo
# Processing Record 45 of Set 11 | baie-comeau
# Processing Record 46 of Set 11 | tiksi
# Processing Record 47 of Set 11 | tornio
# Processing Record 48 of Set 11 | grand river south east
# grand river south east not found. Skipping...
# Processing Record 49 of Set 11 | marsh harbour
# Processing Record 50 of Set 11 | watrous
# Processing Record 1 of Set 12 | port hueneme
# Processing Record 2 of Set 12 | portales
# Processing Record 3 of Set 12 | eskil
# Processing Record 4 of Set 12 | yabelo
# Processing Record 5 of Set 12 | gnjilane
# Processing Record 6 of Set 12 | pangoa
# Processing Record 7 of Set 12 | tual
# Processing Record 8 of Set 12 | tecpan
# Processing Record 9 of Set 12 | sinnamary
# Processing Record 10 of Set 12 | isangel
# Processing Record 11 of Set 12 | manga
# Processing Record 12 of Set 12 | vrangel
# Processing Record 13 of Set 12 | grande-riviere
# grande-riviere not found. Skipping...
# Processing Record 14 of Set 12 | santa luzia
# Processing Record 15 of Set 12 | san jeronimo
# Processing Record 16 of Set 12 | sarakhs
# Processing Record 17 of Set 12 | sabang
# Processing Record 18 of Set 12 | jabiru
# jabiru not found. Skipping...
# Processing Record 19 of Set 12 | genhe
# Processing Record 20 of Set 12 | andenes
# Processing Record 21 of Set 12 | sorong
# Processing Record 22 of Set 12 | ladybrand
# Processing Record 23 of Set 12 | kaiyuan
# Processing Record 24 of Set 12 | geraldton
# Processing Record 25 of Set 12 | mersing
# Processing Record 26 of Set 12 | anadyr
# Processing Record 27 of Set 12 | bhawanipatna
# Processing Record 28 of Set 12 | stromness
# Processing Record 29 of Set 12 | homer
# Processing Record 30 of Set 12 | oum hadjer
# Processing Record 31 of Set 12 | krasnoselkup
# Processing Record 32 of Set 12 | cozumel
# Processing Record 33 of Set 12 | saint-georges
# Processing Record 34 of Set 12 | maragogi
# Processing Record 35 of Set 12 | bilma
# Processing Record 36 of Set 12 | bilibino
# Processing Record 37 of Set 12 | kudahuvadhoo
# Processing Record 38 of Set 12 | seymchan
# Processing Record 39 of Set 12 | pontal
# Processing Record 40 of Set 12 | wolverhampton
# Processing Record 41 of Set 12 | biltine
# Processing Record 42 of Set 12 | verkhnevilyuysk
# Processing Record 43 of Set 12 | brae
# Processing Record 44 of Set 12 | salym
# Processing Record 45 of Set 12 | xiaoweizhai
# Processing Record 46 of Set 12 | dzhusaly
# dzhusaly not found. Skipping...
# Processing Record 47 of Set 12 | caruray
# Processing Record 48 of Set 12 | archidona
# Processing Record 49 of Set 12 | eureka
# Processing Record 50 of Set 12 | tuggurt
# tuggurt not found. Skipping...
# Processing Record 1 of Set 13 | mayo
# Processing Record 2 of Set 13 | umzimvubu
# umzimvubu not found. Skipping...
# Processing Record 3 of Set 13 | panaba
# Processing Record 4 of Set 13 | vieux-habitants
# Processing Record 5 of Set 13 | puerto quijarro
# Processing Record 6 of Set 13 | arona
# Processing Record 7 of Set 13 | constitucion
# Processing Record 8 of Set 13 | vadso
# Processing Record 9 of Set 13 | talnakh
# Processing Record 10 of Set 13 | shchelyayur
# shchelyayur not found. Skipping...
# Processing Record 11 of Set 13 | palamos
# Processing Record 12 of Set 13 | shaowu
# Processing Record 13 of Set 13 | grand-lahou
# Processing Record 14 of Set 13 | cardston
# Processing Record 15 of Set 13 | warwick
# Processing Record 16 of Set 13 | nehe
# Processing Record 17 of Set 13 | aska
# Processing Record 18 of Set 13 | izhma
# Processing Record 19 of Set 13 | chapada dos guimaraes
# Processing Record 20 of Set 13 | fushan
# Processing Record 21 of Set 13 | ganzhou
# Processing Record 22 of Set 13 | chicama
# Processing Record 23 of Set 13 | magadan
# Processing Record 24 of Set 13 | menongue
# Processing Record 25 of Set 13 | saint-lo
# Processing Record 26 of Set 13 | ngunguru
# Processing Record 27 of Set 13 | karema
# Processing Record 28 of Set 13 | zabol
# Processing Record 29 of Set 13 | bandiagara
# Processing Record 30 of Set 13 | mangrol
# Processing Record 31 of Set 13 | manicore
# Processing Record 32 of Set 13 | derzhavinsk
# Processing Record 33 of Set 13 | skegness
# Processing Record 34 of Set 13 | sioux lookout
# Processing Record 35 of Set 13 | deputatskiy
# Processing Record 36 of Set 13 | palestine
# Processing Record 37 of Set 13 | ulaangom
# Processing Record 38 of Set 13 | east norriton
# Processing Record 39 of Set 13 | hsinchu
# Processing Record 40 of Set 13 | altay
# Processing Record 41 of Set 13 | kalmunai
# Processing Record 42 of Set 13 | teplodar
# Processing Record 43 of Set 13 | maymanak
# maymanak not found. Skipping...
# Processing Record 44 of Set 13 | ugoofaaru
# Processing Record 45 of Set 13 | las vegas
# Processing Record 46 of Set 13 | sentyabrskiy
# sentyabrskiy not found. Skipping...
# Processing Record 47 of Set 13 | ha tinh
# Processing Record 48 of Set 13 | kiama
# Processing Record 49 of Set 13 | pochutla
# Processing Record 50 of Set 13 | tateyama
# Processing Record 1 of Set 14 | maghama
# maghama not found. Skipping...
# Processing Record 2 of Set 14 | bargal
# bargal not found. Skipping...
# Processing Record 3 of Set 14 | rumonge
# Processing Record 4 of Set 14 | boshnyakovo
# Processing Record 5 of Set 14 | jambi
# Processing Record 6 of Set 14 | jiuquan
# Processing Record 7 of Set 14 | burns lake
# Processing Record 8 of Set 14 | coetupo
# coetupo not found. Skipping...
# Processing Record 9 of Set 14 | katsuura
# Processing Record 10 of Set 14 | pleasanton
# Processing Record 11 of Set 14 | yambio
# Processing Record 12 of Set 14 | monte aprazivel
# Processing Record 13 of Set 14 | montoro
# Processing Record 14 of Set 14 | vagur
# Processing Record 15 of Set 14 | feni
# Processing Record 16 of Set 14 | kupang
# Processing Record 17 of Set 14 | cap-aux-meules
# Processing Record 18 of Set 14 | yunjinghong
# yunjinghong not found. Skipping...
# Processing Record 19 of Set 14 | samarai
# Processing Record 20 of Set 14 | shache
# Processing Record 21 of Set 14 | carbonia
# Processing Record 22 of Set 14 | deloraine
# Processing Record 23 of Set 14 | sisimiut
# Processing Record 24 of Set 14 | krasnyy chikoy
# Processing Record 25 of Set 14 | puerto ayacucho
# Processing Record 26 of Set 14 | artyk
# artyk not found. Skipping...
# Processing Record 27 of Set 14 | soyo
# Processing Record 28 of Set 14 | jiangyou
# Processing Record 29 of Set 14 | umba
# Processing Record 30 of Set 14 | henties bay
# Processing Record 31 of Set 14 | naifaru
# Processing Record 32 of Set 14 | nichinan
# Processing Record 33 of Set 14 | thai binh
# Processing Record 34 of Set 14 | zhangye
# Processing Record 35 of Set 14 | prudentopolis
# Processing Record 36 of Set 14 | russell
# Processing Record 37 of Set 14 | padang
# Processing Record 38 of Set 14 | la rioja
# Processing Record 39 of Set 14 | luena
# Processing Record 40 of Set 14 | quelimane
# Processing Record 41 of Set 14 | visnes
# Processing Record 42 of Set 14 | yangjiang
# Processing Record 43 of Set 14 | sehore
# Processing Record 44 of Set 14 | la asuncion
# Processing Record 45 of Set 14 | manzil jamil
# manzil jamil not found. Skipping...
# Processing Record 46 of Set 14 | peterhead
# Processing Record 47 of Set 14 | la paz
# Processing Record 48 of Set 14 | springbok
# Processing Record 49 of Set 14 | stepnyak
# Processing Record 50 of Set 14 | gardan diwal
# gardan diwal not found. Skipping...
# Processing Record 1 of Set 15 | newcastle
# Processing Record 2 of Set 15 | misratah
# Processing Record 3 of Set 15 | maningrida
# Processing Record 4 of Set 15 | wooster
# Processing Record 5 of Set 15 | lochgilphead
# Processing Record 6 of Set 15 | inuvik
# Processing Record 7 of Set 15 | alto vera
# alto vera not found. Skipping...
# Processing Record 8 of Set 15 | kitui
# Processing Record 9 of Set 15 | teguise
# Processing Record 10 of Set 15 | aksu
# Processing Record 11 of Set 15 | noumea
# Processing Record 12 of Set 15 | warrington
# Processing Record 13 of Set 15 | barcelona
# Processing Record 14 of Set 15 | lafiagi
# Processing Record 15 of Set 15 | yarada
# Processing Record 16 of Set 15 | jieshi
# Processing Record 17 of Set 15 | bonthe
# Processing Record 18 of Set 15 | galveston
# Processing Record 19 of Set 15 | hay river
# Processing Record 20 of Set 15 | carlisle
# Processing Record 21 of Set 15 | bow island
# Processing Record 22 of Set 15 | sindi
# Processing Record 23 of Set 15 | nizhnyaya omka
# Processing Record 24 of Set 15 | ancud
# Processing Record 25 of Set 15 | marsabit
# Processing Record 26 of Set 15 | neuquen
# Processing Record 27 of Set 15 | martapura
# Processing Record 28 of Set 15 | krasnokholmskiy
# Processing Record 29 of Set 15 | san juan
# Processing Record 30 of Set 15 | bolivar
# Processing Record 31 of Set 15 | havelock
# Processing Record 32 of Set 15 | jalu
# Processing Record 33 of Set 15 | ustka
# Processing Record 34 of Set 15 | pecos
# Processing Record 35 of Set 15 | kilindoni
# Processing Record 36 of Set 15 | fenoarivo
# Processing Record 37 of Set 15 | lakes entrance
# Processing Record 38 of Set 15 | tavricheskoye
# Processing Record 39 of Set 15 | the pas
# Processing Record 40 of Set 15 | tartagal
# Processing Record 41 of Set 15 | yarkovo
# Processing Record 42 of Set 15 | srednyaya akhtuba
# Processing Record 43 of Set 15 | aswan
# Processing Record 44 of Set 15 | ola
# Processing Record 45 of Set 15 | babanusah
# babanusah not found. Skipping...
# Processing Record 46 of Set 15 | mahadday weyne
# mahadday weyne not found. Skipping...
# Processing Record 47 of Set 15 | mecca
# Processing Record 48 of Set 15 | northam
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data))
# Out:
# 684

# %%
#Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

#assign variable to hold new order of columns
new_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

#apply new order to df
city_data_df = city_data_df[new_order]
city_data_df.head()
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Dombas      NO  62.0696    9.1235      5.72        99          91
# 1          Fuxin      CN  42.0156  121.6589     13.01        47           0
# 2         Ermelo      ZA -26.5333   29.9833     54.54        71          10
# 3  Newport Beach      US  33.6189 -117.9289     63.09        74          75
# 4       Khatanga      RU  71.9667  102.5000    -37.68        99          20
#
#    Wind Speed Current Description
# 0        2.53     overcast clouds
# 1        7.61           clear sky
# 2        3.40           clear sky
# 3        1.01       broken clouds
# 4        2.37          few clouds

# %%
#Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

#Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
